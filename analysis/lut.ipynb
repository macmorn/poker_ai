# %%
import joblib
import pandas as pd

# %%
with open("../card_info_lut.joblib", "rb") as stream:
    card_info_lut = joblib.load(stream)

# %%
card_info_lut
# Out:
# {'pre_flop': {(<Card card=[jack of clubs ♣]>, <Card card=[10 of clubs ♣]>): 14,
#   (<Card card=[queen of clubs ♣]>, <Card card=[10 of clubs ♣]>): 13,
#   (<Card card=[king of clubs ♣]>, <Card card=[10 of clubs ♣]>): 11,
#   (<Card card=[ace of clubs ♣]>, <Card card=[10 of clubs ♣]>): 8,
#   (<Card card=[10 of clubs ♣]>, <Card card=[10 of diamonds ♦]>): 4,
#   (<Card card=[jack of diamonds ♦]>, <Card card=[10 of clubs ♣]>): 24,
#   (<Card card=[queen of diamonds ♦]>, <Card card=[10 of clubs ♣]>): 23,
#   (<Card card=[king of diamonds ♦]>, <Card card=[10 of clubs ♣]>): 21,
#   (<Card card=[ace of diamonds ♦]>, <Card card=[10 of clubs ♣]>): 18,
#   (<Card card=[10 of clubs ♣]>, <Card card=[10 of hearts ♥]>): 4,
#   (<Card card=[jack of hearts ♥]>, <Card card=[10 of clubs ♣]>): 24,
#   (<Card card=[queen of hearts ♥]>, <Card card=[10 of clubs ♣]>): 23,
#   (<Card card=[king of hearts ♥]>, <Card card=[10 of clubs ♣]>): 21,
# ...

# %%
pd.DataFrame(card_info_lut)
# Out:
#                                                                                                                                                                       pre_flop  \
# <Card card=[jack of clubs ♣]>  <Card card=[10 of clubs ♣]>    NaN                             NaN                             NaN                            NaN NaN       NaN
# <Card card=[queen of clubs ♣]> <Card card=[10 of clubs ♣]>    NaN                             NaN                             NaN                            NaN NaN       NaN
# <Card card=[king of clubs ♣]>  <Card card=[10 of clubs ♣]>    NaN                             NaN                             NaN                            NaN NaN       NaN
# <Card card=[ace of clubs ♣]>   <Card card=[10 of clubs ♣]>    NaN                             NaN                             NaN                            NaN NaN       NaN
# ...
